# %% [markdown]
# <a href="https://colab.research.google.com/github/AranyaJ633021028/bsc_dpdm22/blob/main/data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import File Google Sheets

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %% [markdown]
# ###House

# %%
house = pd.read_excel(f'https://docs.google.com/spreadsheets/d/17Z0qVeXHI_vl6m_kPjICy7id7eVaAejWYQ-kUt0kiVg/export?format=xlsx', sheet_name ='บ้าน')
h1 = house[house['ID ผู้ประเมิน']==1]
h1 = h1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
h2 = house[house['ID ผู้ประเมิน']==2]
h2 = h2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
h1MAPE = MAPE(h1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(h1['ราคาทรัพย์']))
h2MAPE = MAPE(h2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(h2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {h1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {h2MAPE*100:.2f}%')
h2['ประเมิน1'] = h2['post id'].map(h1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
h2_h = h2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(h2_h['ประเมินราคาซื้อ-ขาย'],h2_h['ประเมิน1'])
two2one = MAPE(h2_h['ประเมิน1'],h2_h['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(h2_h)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 14.50%
# นักประเมิน คนที่ 2 = 11.14%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 14.56%
# จำนวนทรัพย์ทั้งหมด 498 ทรัพย์

# %%
house = h2_h[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย']]
house.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ##Land

# %%
land = pd.read_excel(f'https://docs.google.com/spreadsheets/d/17Z0qVeXHI_vl6m_kPjICy7id7eVaAejWYQ-kUt0kiVg/export?format=xlsx', sheet_name ='land')
l1 = land[land['ID ผู้ประเมิน']==1]
l1 = l1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
l2 = land[land['ID ผู้ประเมิน']==2]
l2 = l2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
l1MAPE = MAPE(l1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(l1['ราคาทรัพย์']))
l2MAPE = MAPE(l2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(l2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {l1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {l2MAPE*100:.2f}%')
l2['ประเมิน1'] = l2['post id'].map(l1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
l2_l = l2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(l2_l['ประเมินราคาซื้อ-ขาย'],l2_l['ประเมิน1'])
two2one = MAPE(l2_l['ประเมิน1'],l2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(l2_l)} ทรัพย์')
land = l2_l[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย']]
land.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 79.74%
# นักประเมิน คนที่ 2 = 43.70%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ##Townhome

# %%
th = pd.read_excel(f'https://docs.google.com/spreadsheets/d/17Z0qVeXHI_vl6m_kPjICy7id7eVaAejWYQ-kUt0kiVg/export?format=xlsx', sheet_name ='ทาวน์โฮม')
t1 = th[th['ID ผู้ประเมิน']==1]
t1 = t1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
t2 = th[th['ID ผู้ประเมิน']==2]
t2 = t2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
t1MAPE = MAPE(t1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(t1['ราคาทรัพย์']))
t2MAPE = MAPE(t2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(t2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {t1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {t2MAPE*100:.2f}%')
t2['ประเมิน1'] = t2['post id'].map(t1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
t2_t = t2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(t2_t['ประเมินราคาซื้อ-ขาย'],t2_t['ประเมิน1'])
two2one = MAPE(t2_t['ประเมิน1'],t2_t['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(t2_t)} ทรัพย์')
th = t2_t[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย']]
th.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 15.26%
# นักประเมิน คนที่ 2 = 12.20%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ##Commercial building

# %%
build = pd.read_excel(f'https://docs.google.com/spreadsheets/d/17Z0qVeXHI_vl6m_kPjICy7id7eVaAejWYQ-kUt0kiVg/export?format=xlsx', sheet_name ='อาคารพาณิชย์')
b1 = build[build['ID ผู้ประเมิน']==1]
b1 = b1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
b2 = build[build['ID ผู้ประเมิน']==2]
b2 = b2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
b1MAPE = MAPE(b1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(b1['ราคาทรัพย์']))
b2MAPE = MAPE(b2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(b2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {b1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {b2MAPE*100:.2f}%')
b2['ประเมิน1'] = b2['post id'].map(b1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
b2_b = b2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(b2_b['ประเมินราคาซื้อ-ขาย'],b2_b['ประเมิน1'])
two2one = MAPE(b2_b['ประเมิน1'],b2_b['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(b2_b)} ทรัพย์')
b = b2_b[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย']]
b.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 20.25%
# นักประเมิน คนที่ 2 = 9.49%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 12.53%
# จำนวนทรัพย์ทั้งหมด 91 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# # HW2
# แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %% [markdown]
# ##House

# %%
house['check1']=house.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
house['check2']=house.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
check1 = list()
for row in house.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
house['check1'] = check1

check2 = list()
for row in house.iterrows():
    check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
house['check2'] = check2

house
# Out:
# <ipython-input-45-5e716591e3f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['check1']=house.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-45-5e716591e3f6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['check2']=house.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# <ipython-input-45-5e716591e3f6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['check1'] = check1
# <ipython-input-45-5e716591e3f6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['check2'] = check2
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25     2890000  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33     2600000  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495     6050000  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564     4400000  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566     2750000  2500000.0  2500000.0
# ...                                    ...         ...        ...        ...
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 1212  https://nayoo.co/khonkaen/posts/6256      610000   700000.0   500000.0
# 1214  https://nayoo.co/khonkaen/posts/6257      295000   500000.0   300000.0
# 1216  https://nayoo.co/khonkaen/posts/6258      615000   600000.0   500000.0
# 1218  https://nayoo.co/khonkaen/posts/6260      620000   750000.0   700000.0
#
#         check1    check2
# 1     1.156000  1.070370
# 3     1.181818  1.083333
# 5     1.210000  1.487603
# 7     1.257143  1.189189
# 9     1.100000  1.100000
# ...        ...       ...
# 1210  2.115385  1.153846
# 1212  1.147541  1.220000
# 1214  1.694915  1.016949
# 1216  1.025000  1.230000
# 1218  1.209677  1.129032
#
# [498 rows x 6 columns]

# %%
house.sort_values(by=['check1'],ascending=False)  # ตัด 802
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 802   https://nayoo.co/khonkaen/posts/3208    23900000  2300000.0  2200000.0
# 1070  https://nayoo.co/khonkaen/posts/6037     1450000  3500000.0  3000000.0
# 228    https://nayoo.co/khonkaen/posts/525     1933000   830000.0  2200000.0
# 1210  https://nayoo.co/khonkaen/posts/6255      260000   550000.0   300000.0
# 767   https://nayoo.co/khonkaen/posts/2321      465000   900000.0   400000.0
# ...                                    ...         ...        ...        ...
# 266    https://nayoo.co/khonkaen/posts/585     3300000  3300000.0  3500000.0
# 63    https://nayoo.co/khonkaen/posts/2033     1200000  1200000.0  1000000.0
# 652   https://nayoo.co/khonkaen/posts/2256     2000000  2000000.0  2200000.0
# 43    https://nayoo.co/khonkaen/posts/1128     4200000  4200000.0  5000000.0
# 928   https://nayoo.co/khonkaen/posts/3819     2500000  2500000.0  2900000.0
#
#          check1     check2
# 802   10.391304  10.863636
# 1070   2.413793   2.068966
# 228    2.328916   1.138127
# 1210   2.115385   1.153846
# 767    1.935484   1.162500
# ...         ...        ...
# 266    1.000000   1.060606
# 63     1.000000   1.200000
# 652    1.000000   1.100000
# 43     1.000000   1.190476
# 928    1.000000   1.160000
#
# [498 rows x 6 columns]

# %%
house.sort_values(by=['check2'],ascending=False) #ตัด 802 / ลด 0 544 /ลด 0 292
# Out:
#                                     post id  ราคาทรัพย์   ประเมิน1  \
# 802    https://nayoo.co/khonkaen/posts/3208    23900000  2300000.0
# 544    https://nayoo.co/khonkaen/posts/1619     2850000  2500000.0
# 292     https://nayoo.co/khonkaen/posts/622     8019000  7900000.0
# 75        https://nayoo.co/khonkaen/posts/1      390000   600000.0
# 1070   https://nayoo.co/khonkaen/posts/6037     1450000  3500000.0
# ...                                     ...         ...        ...
# 806    https://nayoo.co/khonkaen/posts/3210     2390000  2500000.0
# 169   https://nayoo.co/khonkaen/posts/11264     6500000  5600000.0
# 763    https://nayoo.co/khonkaen/posts/2319     1200000  1200000.0
# 1149   https://nayoo.co/khonkaen/posts/6096     2200000  2200000.0
# 564    https://nayoo.co/khonkaen/posts/1834     1700000  1500000.0
#
#         ประเมิน2     check1     check2
# 802    2200000.0  10.391304  10.863636
# 544   29000000.0   1.140000  10.175439
# 292   80000000.0   1.015063   9.976306
# 75     1300000.0   1.538462   3.333333
# 1070   3000000.0   2.413793   2.068966
# ...          ...        ...        ...
# 806    2390000.0   1.046025   1.000000
# 169    6500000.0   1.160714   1.000000
# 763    1200000.0   1.000000   1.000000
# 1149   2200000.0   1.000000   1.000000
# 564    1700000.0   1.133333   1.000000
#
# [498 rows x 6 columns]

# %% [markdown]
# ##Land

# %%
land['check1']=land.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
land['check2']=land.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
check1 = list()
for row in land.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
land['check1'] = check1

check2 = list()
for row in land.iterrows():
    check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
land['check2'] = check2

land
# Out:
# <ipython-input-48-3e4316ec3602>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land['check1']=land.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-48-3e4316ec3602>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land['check2']=land.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# <ipython-input-48-3e4316ec3602>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land['check1'] = check1
# <ipython-input-48-3e4316ec3602>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land['check2'] = check2
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2    check1    check2
# 1     2000000.0  1.555556  1.400000
# 4    12000000.0  1.862500  1.241667
# 7    70000000.0  5.000000  1.285714
# 10   60000000.0  1.857143  1.083333
# 13    2500000.0  1.363636  1.200000
# ..          ...       ...       ...
# 200   4000000.0  1.250000  1.250000
# 202    750000.0  1.500000  1.000000
# 204   2500000.0  1.325000  1.060000
# 206   1500000.0  1.153846  1.153846
# 208   2800000.0  1.200000  1.071429
#
# [100 rows x 6 columns]

# %%
land.sort_values(by=['check1'],ascending=False) # 194 เติม 0 /112 ลด 0 /47,58 ตัด
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000   4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000  32000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000  14000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# ..                                     ...         ...         ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000   4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000   1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000   1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000    650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000   2500000.0
#
#        ประเมิน2     check1     check2
# 194  75000000.0  20.000000   1.200000
# 112   2000000.0  12.307692   1.300000
# 47   18000000.0  10.208333  13.611111
# 58   11000000.0   8.571429  10.909091
# 7    70000000.0   5.000000   1.285714
# ..          ...        ...        ...
# 182   4000000.0   1.025641   1.025641
# 78     800000.0   1.020408   1.225000
# 100   1200000.0   1.010101   1.237500
# 122    700000.0   1.000000   1.076923
# 130   2200000.0   1.000000   1.136364
#
# [100 rows x 6 columns]

# %%
land.sort_values(by=['check2'],ascending=False)  # 47,58 ตัด / 148 ลด 0/188 ลด 0
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 47    https://nayoo.co/khonkaen/posts/7349   245000000  24000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   120000000  14000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550   6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000   2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000   1600000.0
# ..                                     ...         ...         ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000   2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000  10000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000   2800000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000  12000000.0
#
#        ประเมิน2     check1     check2
# 47   18000000.0  10.208333  13.611111
# 58   11000000.0   8.571429  10.909091
# 148  80000000.0   1.229092  10.848120
# 188  24000000.0   1.086957  10.434783
# 144   9000000.0   1.062500   5.294118
# ..          ...        ...        ...
# 104   8000000.0   2.885714   1.010000
# 60    8000000.0   1.251564   1.001252
# 202    750000.0   1.500000   1.000000
# 158   3500000.0   1.250000   1.000000
# 37   14000000.0   1.166667   1.000000
#
# [100 rows x 6 columns]

# %% [markdown]
# ##Townhome

# %%
th['check1']=th.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
th['check2']=th.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
check1 = list()
for row in th.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
th['check1'] = check1

check2 = list()
for row in th.iterrows():
    check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
th['check2'] = check2

th
# Out:
# <ipython-input-51-a14a42651373>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th['check1']=th.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-51-a14a42651373>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th['check2']=th.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# <ipython-input-51-a14a42651373>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th['check1'] = check1
# <ipython-input-51-a14a42651373>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   th['check2'] = check2
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580     3850000  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547     1105000  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551     1440000  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434     2000000  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501     1790000  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367     1590000  1700000.0  1700000.0
#
#        check1    check2
# 1    1.492857  1.435407
# 3    1.335714  1.604278
# 5    1.388889  1.587302
# 7    1.100000  1.203125
# 9    1.838235  1.470588
# ..        ...       ...
# 235  1.105000  1.085973
# 236  1.041667  1.180556
# 237  1.250000  1.052632
# 238  1.118750  1.052941
# 239  1.069182  1.069182
#
# [120 rows x 6 columns]

# %%
th.sort_values(by=['check1'],ascending=False) #ตัด 176
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000   350000.0   400000.0
# 9      https://nayoo.co/khonkaen/posts/582      544000  1000000.0   800000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000   650000.0   700000.0
# 216  https://nayoo.co/khonkaen/posts/17535      840000  1300000.0  1000000.0
# 1      https://nayoo.co/khonkaen/posts/548     1045000   700000.0  1500000.0
# ..                                     ...         ...        ...        ...
# 162   https://nayoo.co/khonkaen/posts/2242     1610000  1600000.0  1600000.0
# 228  https://nayoo.co/khonkaen/posts/17923     1990000  2000000.0  2200000.0
# 167   https://nayoo.co/khonkaen/posts/2829     2490000  2500000.0  2300000.0
# 200  https://nayoo.co/khonkaen/posts/13411     3200000  3200000.0  3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503     1500000  1500000.0  1300000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 9    1.838235  1.470588
# 206  1.669231  1.550000
# 216  1.547619  1.190476
# 1    1.492857  1.435407
# ..        ...       ...
# 162  1.006250  1.006250
# 228  1.005025  1.105528
# 167  1.004016  1.082609
# 200  1.000000  1.000000
# 203  1.000000  1.153846
#
# [120 rows x 6 columns]

# %%
th.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176   https://nayoo.co/khonkaen/posts/3528     2190000   350000.0   400000.0
# 234  https://nayoo.co/khonkaen/posts/18090     2850000  2800000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549      935000   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579     2520000  3500000.0  4000000.0
# 206  https://nayoo.co/khonkaen/posts/17507     1085000   650000.0   700000.0
# ..                                     ...         ...        ...        ...
# 202  https://nayoo.co/khonkaen/posts/15111     2200000  2500000.0  2200000.0
# 209  https://nayoo.co/khonkaen/posts/17511     1700000  1500000.0  1700000.0
# 212  https://nayoo.co/khonkaen/posts/17516     1800000  1700000.0  1800000.0
# 213  https://nayoo.co/khonkaen/posts/17518     1200000  1100000.0  1200000.0
# 152   https://nayoo.co/khonkaen/posts/2011     1100000   900000.0  1100000.0
#
#        check1    check2
# 176  6.257143  5.475000
# 234  1.017857  1.900000
# 3    1.335714  1.604278
# 5    1.388889  1.587302
# 206  1.669231  1.550000
# ..        ...       ...
# 202  1.136364  1.000000
# 209  1.133333  1.000000
# 212  1.058824  1.000000
# 213  1.090909  1.000000
# 152  1.222222  1.000000
#
# [120 rows x 6 columns]

# %% [markdown]
# ##Commercial Building

# %%
b['check1']=b.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
b['check2']=b.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
check1 = list()
for row in b.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
b['check1'] = check1

check2 = list()
for row in b.iterrows():
    check2.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
b['check2'] = check2

b
# Out:
# <ipython-input-54-ff0a554fec3f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['check1']=b.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
# <ipython-input-54-ff0a554fec3f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['check2']=b.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมิน2']),axis=1)
# <ipython-input-54-ff0a554fec3f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['check1'] = check1
# <ipython-input-54-ff0a554fec3f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['check2'] = check2
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/6     6600000   6000000.0   8000000.0
# 3      https://nayoo.co/khonkaen/posts/17    11400000  12000000.0  12000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 7      https://nayoo.co/khonkaen/posts/22     3500000   4000000.0   4000000.0
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# ..                                    ...         ...         ...         ...
# 183  https://nayoo.co/khonkaen/posts/6168     2652000   3000000.0   2700000.0
# 185  https://nayoo.co/khonkaen/posts/6169     3851000   3800000.0   4000000.0
# 187  https://nayoo.co/khonkaen/posts/6176     3410000   3200000.0   3500000.0
# 191  https://nayoo.co/khonkaen/posts/7137     3900000   3600000.0   4000000.0
# 199  https://nayoo.co/khonkaen/posts/7705     2200000   2500000.0   2000000.0
#
#        check1    check2
# 1    1.100000  1.212121
# 3    1.052632  1.052632
# 5    1.666667  1.125000
# 7    1.142857  1.142857
# 9    1.772727  1.300000
# ..        ...       ...
# 183  1.131222  1.018100
# 185  1.013421  1.038691
# 187  1.065625  1.026393
# 191  1.083333  1.025641
# 199  1.136364  1.100000
#
# [91 rows x 6 columns]

# %%
b.sort_values(by=['check1'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9      https://nayoo.co/khonkaen/posts/24     3900000   2200000.0   3000000.0
# 5      https://nayoo.co/khonkaen/posts/21    22500000  13500000.0  20000000.0
# 169  https://nayoo.co/khonkaen/posts/6043     2240000   3500000.0   3000000.0
# 87    https://nayoo.co/khonkaen/posts/707     1450000   2200000.0   3200000.0
# 81    https://nayoo.co/khonkaen/posts/701     1925000   2700000.0   2000000.0
# ..                                    ...         ...         ...         ...
# 61    https://nayoo.co/khonkaen/posts/643     4180000   4200000.0   4200000.0
# 65    https://nayoo.co/khonkaen/posts/651     2200000   2200000.0   2000000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000   3000000.0   6000000.0
# 177  https://nayoo.co/khonkaen/posts/6123     2200000   2200000.0   2200000.0
# 17    https://nayoo.co/khonkaen/posts/498     7000000   7000000.0   8000000.0
#
#        check1    check2
# 9    1.772727  1.300000
# 5    1.666667  1.125000
# 169  1.562500  1.339286
# 87   1.517241  2.206897
# 81   1.402597  1.038961
# ..        ...       ...
# 61   1.004785  1.004785
# 65   1.000000  1.100000
# 161  1.000000  2.000000
# 177  1.000000  1.000000
# 17   1.000000  1.142857
#
# [91 rows x 6 columns]

# %%
b.sort_values(by=['check2'],ascending=False)
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 163  https://nayoo.co/khonkaen/posts/6009     2250000  2700000.0  5000000.0
# 87    https://nayoo.co/khonkaen/posts/707     1450000  2200000.0  3200000.0
# 161  https://nayoo.co/khonkaen/posts/5995     3000000  3000000.0  6000000.0
# 49    https://nayoo.co/khonkaen/posts/602     2520000  3300000.0  3500000.0
# 169  https://nayoo.co/khonkaen/posts/6043     2240000  3500000.0  3000000.0
# ..                                    ...         ...        ...        ...
# 121  https://nayoo.co/khonkaen/posts/2180     5000000  4000000.0  5000000.0
# 109  https://nayoo.co/khonkaen/posts/1885     3500000  3400000.0  3500000.0
# 107  https://nayoo.co/khonkaen/posts/1858     1500000  2000000.0  1500000.0
# 101  https://nayoo.co/khonkaen/posts/1614     2500000  2700000.0  2500000.0
# 127  https://nayoo.co/khonkaen/posts/2247     1900000  2500000.0  1900000.0
#
#        check1    check2
# 163  1.200000  2.222222
# 87   1.517241  2.206897
# 161  1.000000  2.000000
# 49   1.309524  1.388889
# 169  1.562500  1.339286
# ..        ...       ...
# 121  1.250000  1.000000
# 109  1.029412  1.000000
# 107  1.333333  1.000000
# 101  1.080000  1.000000
# 127  1.315789  1.000000
#
# [91 rows x 6 columns]

# %% [markdown]
# ### Retake MAPE

# %% [markdown]
# ####House

# %%
House = pd.read_excel(f'https://docs.google.com/spreadsheets/d/13oWup4M1rh5Cq4RMIvoc5d9Oe59DZS0w/export?format=xlsx', sheet_name ='บ้าน')
h1 = House[House['ID ผู้ประเมิน']==1]
h1 = h1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
h2 = House[House['ID ผู้ประเมิน']==2]
h2 = h2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
h1MAPE = MAPE(h1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(h1['ราคาทรัพย์']))
h2MAPE = MAPE(h2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(h2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {h1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {h2MAPE*100:.2f}%')
h2['ประเมิน1'] = h2['post id'].map(h1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
h2_h = h2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(h2_h['ประเมินราคาซื้อ-ขาย'],h2_h['ประเมิน1'])
two2one = MAPE(h2_h['ประเมิน1'],h2_h['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(h2_h)} ทรัพย์')
home = h2_h[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย','ความมั่นใจในการเมินราคาทรัพย์','ให้คะแนนทรัพย์']]
home.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 12.97%
# นักประเมิน คนที่ 2 = 8.82%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 12.45%
# จำนวนทรัพย์ทั้งหมด 497 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ####Land

# %%
Land = pd.read_excel(f'https://docs.google.com/spreadsheets/d/13oWup4M1rh5Cq4RMIvoc5d9Oe59DZS0w/export?format=xlsx', sheet_name ='Land')
l1 = Land[Land['ID ผู้ประเมิน']==1]
l1 = l1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
l2 = Land[Land['ID ผู้ประเมิน']==2]
l2 = l2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
l1MAPE = MAPE(l1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(l1['ราคาทรัพย์']))
l2MAPE = MAPE(l2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(l2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {l1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {l2MAPE*100:.2f}%')
l2['ประเมิน1'] = l2['post id'].map(l1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
l2_l = l2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(l2_l['ประเมินราคาซื้อ-ขาย'],l2_l['ประเมิน1'])
two2one = MAPE(l2_l['ประเมิน1'],l2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(l2_l)} ทรัพย์')
land = l2_l[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย','ความมั่นใจในการเมินราคาทรัพย์','ให้คะแนนทรัพย์']]
land.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 45.13%
# นักประเมิน คนที่ 2 = 19.89%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 32.23%
# จำนวนทรัพย์ทั้งหมด 98 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ####Townhome

# %%
Th = pd.read_excel(f'https://docs.google.com/spreadsheets/d/13oWup4M1rh5Cq4RMIvoc5d9Oe59DZS0w/export?format=xlsx', sheet_name ='ทาวน์โฮม')
t1 = Th[Th['ID ผู้ประเมิน']==1]
t1 = t1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
t2 = Th[Th['ID ผู้ประเมิน']==2]
t2 = t2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
t1MAPE = MAPE(t1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(t1['ราคาทรัพย์']))
t2MAPE = MAPE(t2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(t2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {t1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {t2MAPE*100:.2f}%')
t2['ประเมิน1'] = t2['post id'].map(t1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
t2_t = t2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(t2_t['ประเมินราคาซื้อ-ขาย'],t2_t['ประเมิน1'])
two2one = MAPE(t2_t['ประเมิน1'],t2_t['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(t2_t)} ทรัพย์')
th = t2_t[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย','ความมั่นใจในการเมินราคาทรัพย์','ให้คะแนนทรัพย์']]
th.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 10.97%
# นักประเมิน คนที่ 2 = 8.54%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 10.89%
# จำนวนทรัพย์ทั้งหมด 119 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ####Commercial Building

# %%
Build = pd.read_excel(f'https://docs.google.com/spreadsheets/d/13oWup4M1rh5Cq4RMIvoc5d9Oe59DZS0w/export?format=xlsx', sheet_name ='อาคารพาณิชย์')
b1 = Build[Build['ID ผู้ประเมิน']==1]
b1 = b1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])  #ในที่นี้ควร Dropna เพราะไม่ทราบค่า //เเต่มีวิธีที่ดีกว่า คือการที่ดูปัจจัยแวดล้อมแล้วนำมาวิเคราะห์หาแนวโน้มของข้อมูลิล // เอาทุกค่าที่่มีอยู่มาสร้างโมเดลเพื่อทำนายค่าที่หายไป
b2 = Build[Build['ID ผู้ประเมิน']==2]
b2 = b2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
b1MAPE = MAPE(b1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(b1['ราคาทรัพย์']))
b2MAPE = MAPE(b2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(b2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {b1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {b2MAPE*100:.2f}%')
b2['ประเมิน1'] = b2['post id'].map(b1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
b2_b = b2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน1','ราคาทรัพย์'])
one2two = MAPE(b2_b['ประเมินราคาซื้อ-ขาย'],b2_b['ประเมิน1'])
two2one = MAPE(b2_b['ประเมิน1'],b2_b['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้งสอง {((one2two)+(two2one))*50:.2f}%') #เฉลี่ยเพื่อหาความผิดพลาดระหว่าง 1 และ 2
print(f'จำนวนทรัพย์ทั้งหมด {len(b2_b)} ทรัพย์')
b = b2_b[['post id','ราคาทรัพย์','ประเมิน1', 'ประเมินราคาซื้อ-ขาย','ความมั่นใจในการเมินราคาทรัพย์','ให้คะแนนทรัพย์']]
b.rename(columns={'ประเมินราคาซื้อ-ขาย': 'ประเมิน2'},inplace=True)
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 20.25%
# นักประเมิน คนที่ 2 = 9.49%
# ความผิดพลาดระหว่างนักประเมินทั้งสอง 12.53%
# จำนวนทรัพย์ทั้งหมด 91 ทรัพย์
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# #HW3
# Visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน) - ความมั่นใจ - ให้คะแนนทรัพย์

# %% [markdown]
# ##Trend
# ดูแนวโน้มระหว่างราคาทรัพย์และการประเมินราคา

# %%
mpl.rcParams['figure.figsize']=[30,15]
plt.suptitle('การเปรียบเทียบแนวโน้มของการตั้งราคาทรัพย์ของผู้ขายและการประเมินราคาของผู้ประเมินทั้ง 2 คน',fontsize = 40)

plt.subplot(2,2,1)
plt.plot(house['ราคาทรัพย์'], color = "#0099FF", linewidth = '10',label = 'ราคาทรัพย์')
plt.plot(house['ประเมิน1'], color = "#CCCCFF", alpha = 1,linewidth = '6',label = 'ประเมินโดย 1')
plt.plot(house['ประเมิน2'], color = "#99FFCC" ,alpha = 1,linewidth = '3',label = 'ประเมินโดย 2')
plt.title('บ้าน',fontsize=25)
plt.ylabel('ราคา(สิบล้านบาท)',fontsize=16)
plt.legend(loc='upper right' ,fontsize = 20,)


plt.subplot(2,2,2)
plt.plot(land['ราคาทรัพย์'], color = "#0099FF", linewidth = '10',label = 'ราคาทรัพย์')
plt.plot(land['ประเมิน1'], color = "#CCCCFF", alpha = 1,linewidth = '6',label = 'ประเมินโดย 1')
plt.plot(land['ประเมิน2'], color = "#99FFCC" ,alpha = 1,linewidth = '3',label = 'ประเมินโดย 2')
plt.title('ที่ดิน',fontsize=25)
plt.ylabel('ราคา(ร้อยล้านบาท)',fontsize=16)
plt.legend(loc='upper right' ,fontsize = 20)


plt.subplot(2,2,3)
plt.plot(th['ราคาทรัพย์'], color = "#0099FF", linewidth = '10',label = 'ราคาทรัพย์')
plt.plot(th['ประเมิน1'], color = "#CCCCFF", alpha = 1,linewidth = '6',label = 'ประเมินโดย 1')
plt.plot(th['ประเมิน2'], color = "#99FFCC" ,alpha = 1,linewidth = '3',label = 'ประเมินโดย 2')
plt.title('ทาวน์โฮม',fontsize=25)
plt.ylabel('ราคา(ล้านบาท)',fontsize=16)
plt.legend(loc='upper right' ,fontsize = 20)

plt.subplot(2,2,4)
plt.plot(b['ราคาทรัพย์'], color = "#0099FF", linewidth = '10',label = 'ราคาทรัพย์')
plt.plot(b['ประเมิน1'], color = "#CCCCFF", alpha = 1,linewidth = '6',label = 'ประเมินโดย 1')
plt.plot(b['ประเมิน2'], color = "#99FFCC" ,alpha = 1,linewidth = '3',label = 'ประเมินโดย 2')
plt.title('อาคารพาณิชย์',fontsize=25)
plt.ylabel('ราคา(สิบล้านบาท)',fontsize=16)
plt.legend(loc='upper right' ,fontsize = 20)
plt.show()

# %% [markdown]
# ##Correlation

# %%
house.corr().style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_af2be_row0_col0, #T_af2be_row0_col1, #T_af2be_row1_col0, #T_af2be_row1_col1, #T_af2be_row2_col2, #T_af2be_row3_col3, #T_af2be_row4_col4 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_af2be_row0_col2, #T_af2be_row1_col2, #T_af2be_row2_col1, #T_af2be_row3_col4, #T_af2be_row4_col2, #T_af2be_row4_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_af2be_row0_col3 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_af2be_row0_col4 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# #T_af2be_row1_col3, #T_af2be_row1_col4, #T_af2be_row2_col3, #T_af2be_row3_col0, #T_af2be_row3_col1, #T_af2be_row3_col2, #T_af2be_row4_col0, #T_af2be_row4_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_af2be_row2_col0, #T_af2be_row2_col4 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# </style>
# <table id="T_af2be_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ราคาทรัพย์</th>
#       <th class="col_heading level0 col1" >ประเมิน1</th>
#       <th class="col_heading level0 col2" >ประเมิน2</th>
#       <th class="col_heading level0 col3" >check1</th>
#       <th class="col_heading level0 col4" >check2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af2be_level0_row0" class="row_heading level0 row0" >ราคาทรัพย์</th>
#       <td id="T_af2be_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_af2be_row0_col1" class="data row0 col1" >0.920960</td>
#       <td id="T_af2be_row0_col2" class="data row0 col2" >0.574514</td>
#       <td id="T_af2be_row0_col3" class="data row0 col3" >0.242082</td>
#       <td id="T_af2be_row0_col4" class="data row0 col4" >0.212660</td>
#     </tr>
#     <tr>
#       <th id="T_af2be_level0_row1" class="row_heading level0 row1" >ประเมิน1</th>
#       <td id="T_af2be_row1_col0" class="data row1 col0" >0.920960</td>
#       <td id="T_af2be_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_af2be_row1_col2" class="data row1 col2" >0.615317</td>
#       <td id="T_af2be_row1_col3" class="data row1 col3" >-0.086309</td>
#       <td id="T_af2be_row1_col4" class="data row1 col4" >0.007065</td>
#     </tr>
#     <tr>
#       <th id="T_af2be_level0_row2" class="row_heading level0 row2" >ประเมิน2</th>
#       <td id="T_af2be_row2_col0" class="data row2 col0" >0.574514</td>
#       <td id="T_af2be_row2_col1" class="data row2 col1" >0.615317</td>
#       <td id="T_af2be_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_af2be_row2_col3" class="data row2 col3" >-0.062433</td>
#       <td id="T_af2be_row2_col4" class="data row2 col4" >0.552373</td>
#     </tr>
#     <tr>
#       <th id="T_af2be_level0_row3" class="row_heading level0 row3" >check1</th>
#       <td id="T_af2be_row3_col0" class="data row3 col0" >0.242082</td>
#       <td id="T_af2be_row3_col1" class="data row3 col1" >-0.086309</td>
#       <td id="T_af2be_row3_col2" class="data row3 col2" >-0.062433</td>
#       <td id="T_af2be_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_af2be_row3_col4" class="data row3 col4" >0.572331</td>
#     </tr>
#     <tr>
#       <th id="T_af2be_level0_row4" class="row_heading level0 row4" >check2</th>
#       <td id="T_af2be_row4_col0" class="data row4 col0" >0.212660</td>
#       <td id="T_af2be_row4_col1" class="data row4 col1" >0.007065</td>
#       <td id="T_af2be_row4_col2" class="data row4 col2" >0.552373</td>
#       <td id="T_af2be_row4_col3" class="data row4 col3" >0.572331</td>
#       <td id="T_af2be_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
land.corr().style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_378ce_row0_col0, #T_378ce_row0_col2, #T_378ce_row1_col1, #T_378ce_row2_col0, #T_378ce_row2_col2 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_378ce_row0_col1, #T_378ce_row1_col0, #T_378ce_row1_col2 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_378ce_row2_col1 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# </style>
# <table id="T_378ce_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ราคาทรัพย์</th>
#       <th class="col_heading level0 col1" >ประเมิน1</th>
#       <th class="col_heading level0 col2" >ประเมิน2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_378ce_level0_row0" class="row_heading level0 row0" >ราคาทรัพย์</th>
#       <td id="T_378ce_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_378ce_row0_col1" class="data row0 col1" >0.966168</td>
#       <td id="T_378ce_row0_col2" class="data row0 col2" >0.998291</td>
#     </tr>
#     <tr>
#       <th id="T_378ce_level0_row1" class="row_heading level0 row1" >ประเมิน1</th>
#       <td id="T_378ce_row1_col0" class="data row1 col0" >0.966168</td>
#       <td id="T_378ce_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_378ce_row1_col2" class="data row1 col2" >0.970916</td>
#     </tr>
#     <tr>
#       <th id="T_378ce_level0_row2" class="row_heading level0 row2" >ประเมิน2</th>
#       <td id="T_378ce_row2_col0" class="data row2 col0" >0.998291</td>
#       <td id="T_378ce_row2_col1" class="data row2 col1" >0.970916</td>
#       <td id="T_378ce_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
th.corr().style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_09bd6_row0_col0, #T_09bd6_row1_col1, #T_09bd6_row2_col2 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_09bd6_row0_col1, #T_09bd6_row0_col2, #T_09bd6_row1_col2, #T_09bd6_row2_col0, #T_09bd6_row2_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_09bd6_row1_col0 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# </style>
# <table id="T_09bd6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ราคาทรัพย์</th>
#       <th class="col_heading level0 col1" >ประเมิน1</th>
#       <th class="col_heading level0 col2" >ประเมิน2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09bd6_level0_row0" class="row_heading level0 row0" >ราคาทรัพย์</th>
#       <td id="T_09bd6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_09bd6_row0_col1" class="data row0 col1" >0.951368</td>
#       <td id="T_09bd6_row0_col2" class="data row0 col2" >0.940824</td>
#     </tr>
#     <tr>
#       <th id="T_09bd6_level0_row1" class="row_heading level0 row1" >ประเมิน1</th>
#       <td id="T_09bd6_row1_col0" class="data row1 col0" >0.951368</td>
#       <td id="T_09bd6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_09bd6_row1_col2" class="data row1 col2" >0.946121</td>
#     </tr>
#     <tr>
#       <th id="T_09bd6_level0_row2" class="row_heading level0 row2" >ประเมิน2</th>
#       <td id="T_09bd6_row2_col0" class="data row2 col0" >0.940824</td>
#       <td id="T_09bd6_row2_col1" class="data row2 col1" >0.946121</td>
#       <td id="T_09bd6_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
b.corr().style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_36675_row0_col0, #T_36675_row1_col1, #T_36675_row2_col2 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_36675_row0_col1 {
#   background-color: #b3cde3;
#   color: #000000;
# }
# #T_36675_row0_col2 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_36675_row1_col0, #T_36675_row1_col2, #T_36675_row2_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_36675_row2_col0 {
#   background-color: #decbe4;
#   color: #000000;
# }
# </style>
# <table id="T_36675_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ราคาทรัพย์</th>
#       <th class="col_heading level0 col1" >ประเมิน1</th>
#       <th class="col_heading level0 col2" >ประเมิน2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36675_level0_row0" class="row_heading level0 row0" >ราคาทรัพย์</th>
#       <td id="T_36675_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_36675_row0_col1" class="data row0 col1" >0.961883</td>
#       <td id="T_36675_row0_col2" class="data row0 col2" >0.978076</td>
#     </tr>
#     <tr>
#       <th id="T_36675_level0_row1" class="row_heading level0 row1" >ประเมิน1</th>
#       <td id="T_36675_row1_col0" class="data row1 col0" >0.961883</td>
#       <td id="T_36675_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_36675_row1_col2" class="data row1 col2" >0.954673</td>
#     </tr>
#     <tr>
#       <th id="T_36675_level0_row2" class="row_heading level0 row2" >ประเมิน2</th>
#       <td id="T_36675_row2_col0" class="data row2 col0" >0.978076</td>
#       <td id="T_36675_row2_col1" class="data row2 col1" >0.954673</td>
#       <td id="T_36675_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize=(20, 10))
fig.suptitle('Correlation matrix of Data',fontsize = 20)

sns.heatmap(home.corr(),annot = True,cmap = "Pastel1", ax=ax[0,0]).xaxis.tick_top() #.xaxis.tick_top() = ให้ชื่อแกน x ขึ้นไปอยู๋ ด้านบน
ax[0,0].set_title('Correlation matrix of Home Data')

sns.heatmap(land.corr(), cmap = "Pastel1", annot=True, ax=ax[0,1]).xaxis.tick_top()
ax[0,1].set_title('Correlation matrix of Land Data')

sns.heatmap(th.corr(), cmap = "Pastel1", annot=True, ax=ax[1,0]).xaxis.tick_top()
ax[1,0].set_title('Correlation matrix of Townhome Data')

sns.heatmap(b.corr(), cmap = "Pastel1", annot=True, ax=ax[1,1]).xaxis.tick_top()
ax[1,1].set_title('Correlation matrix of Commercial Data')

plt.show()

# %% [markdown]
# ##Compare
# ความมั่นใจในการประเมินทรัพย์ของผู้ประเมินทั้ง 2 คน

# %%
HC = House.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])
LC = Land.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])
TC = Th.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])
CC = Build.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์'])

HC = HC.groupby(['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์'])[['ความมั่นใจในการเมินราคาทรัพย์']].count()
LC = LC.groupby(['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์'])[['ความมั่นใจในการเมินราคาทรัพย์']].count()
TC = TC.groupby(['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์'])[['ความมั่นใจในการเมินราคาทรัพย์']].count()
CC = CC.groupby(['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์'])[['ความมั่นใจในการเมินราคาทรัพย์']].count()

# %%
HC.head()
# Out:
#                                              ความมั่นใจในการเมินราคาทรัพย์
# ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์
# 1             มั่นใจ                                                   608
# 2             มั่นใจ                                                   497

# %%
mpl.rcParams['figure.figsize']=[25,10]

plt.subplot(1,4,1)
plt.bar([1,1.5],HC['ความมั่นใจในการเมินราคาทรัพย์'],ec="#000000", color=['#00FFCC','#FFFFCC'],width=0.5,linewidth = 3) #เปลี่ยนสี เเท่งกราฟ
plt.xticks([1,1.5],['ผู้ประเมินคนที่ 1','ผู้ประเมินคนที่ 2'],fontsize=16)
plt.title('ความมั่นใจในการประเมินราคาบ้าน',fontsize=16)
plt.grid(True)
plt.ylabel('จำนวนความมั่นใจ(ครั้ง)',fontsize=16);

plt.subplot(1,4,2)
LC = LC.iloc[:2,]
plt.bar([1,1.5],LC['ความมั่นใจในการเมินราคาทรัพย์'],ec="#000000", color=['#00FFCC','#FFFFCC'],width=0.5,linewidth = 3) #เปลี่ยนสี เเท่งกราฟ
plt.xticks([1,1.5],['ผู้ประเมินคนที่ 1','ผู้ประเมินคนที่ 2'],fontsize=16)
plt.title('ความมั่นใจในการประเมินราคาที่ดิน',fontsize=16)
plt.grid(True)
plt.ylabel('จำนวนความมั่นใจ(ครั้ง)',fontsize=16);

plt.subplot(1,4,3)
plt.bar([1,1.5],TC['ความมั่นใจในการเมินราคาทรัพย์'],ec="#000000", color=['#00FFCC','#FFFFCC'],width=0.5,linewidth = 3) #เปลี่ยนสี เเท่งกราฟ
plt.xticks([1,1.5],['ผู้ประเมินคนที่ 1','ผู้ประเมินคนที่ 2'],fontsize=16)
plt.title('ความมั่นใจในการประเมินราคาทาวน์โฮม',fontsize=16)
plt.grid(True)
plt.ylabel('จำนวนความมั่นใจ(ครั้ง)',fontsize=16);

plt.subplot(1,4,4)
plt.bar([1,1.5],CC['ความมั่นใจในการเมินราคาทรัพย์'],ec="#000000", color=['#00FFCC','#FFFFCC'],width=0.5,linewidth = 3) #เปลี่ยนสี เเท่งกราฟ
plt.xticks([1,1.5],['ผู้ประเมินคนที่ 1','ผู้ประเมินคนที่ 2'],fontsize=16)
plt.title('ความมั่นใจในการประเมินราคาอาคารพาณิชย์',fontsize=16)
plt.grid(True)
plt.ylabel('จำนวนความมั่นใจ(ครั้ง)',fontsize=16)
plt.show();

# %% [markdown]
# #Pair Plot : Scatter

# %%
#pairplot ข้อมูลผ่านการ Normalization เพื่อปรับให้อยู่ใน standard เดียวกันและพล็อตจุดข้อมูลเพื่อดูการกระจาย
sns.pairplot(home, hue ="ความมั่นใจในการเมินราคาทรัพย์",palette = "Pastel1", diag_kind="hist")# ,kind='reg',plot_kws={'line_kws':{'color':'red'}} เพิ่มเส้นตรงที่เเดง reg
plt.suptitle("บ้าน",fontsize = 20 ,y = 1.05)


sns.pairplot(land, hue ="ความมั่นใจในการเมินราคาทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("ที่ดิน",fontsize = 20,y = 1.05 )


sns.pairplot(th, hue ="ความมั่นใจในการเมินราคาทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("ทาวน์โฮม",fontsize = 20,y = 1.05 )


sns.pairplot(b, hue ="ความมั่นใจในการเมินราคาทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("อาคารพาณิชย์",fontsize = 20,y = 1.05 )

plt.show();

# %%
sns.pairplot(home, hue ="ให้คะแนนทรัพย์",palette = "Pastel1", diag_kind="hist")# ,kind='reg',plot_kws={'line_kws':{'color':'red'}} เพิ่มเส้นตรงที่เเดง reg
plt.suptitle("บ้าน",fontsize = 20 ,y = 1.05)


sns.pairplot(land, hue ="ให้คะแนนทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("ที่ดิน",fontsize = 20,y = 1.05 )


sns.pairplot(th, hue ="ให้คะแนนทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("ทาวน์โฮม",fontsize = 20,y = 1.05 )


sns.pairplot(b, hue ="ให้คะแนนทรัพย์",palette = "Pastel1", diag_kind="hist")
plt.suptitle("อาคารพาณิชย์",fontsize = 20,y = 1.05 )

plt.show();
